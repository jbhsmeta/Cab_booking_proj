# %% [markdown]
# # Mid_Term_Project_Submission_Final

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime,date

# %%
# Loading the Train dataset
df_train=pd.read_csv('train.csv')
df_train_label=pd.read_csv('train_label.csv',header=None,names=['Target'])
df_train['Target']=df_train_label.Target

# %%
# Preparing the Test Dataset
df_test=pd.read_csv('test.csv')
df_test_label=pd.read_csv('test_label.csv',header=None,names=['Target'])
df_test['Target']=df_test_label.Target

# %%
#Checkling Missing Values - Train Data
miss=pd.DataFrame({'Col_name':df_train.columns,'Missing Value?':[any(df_train[x].isnull()) for x in df_train.columns],'Count_': [sum(df_train[y].isnull()) for y in df_train.columns],
                  'Percentage':[sum(df_train[y].isnull())/df_train.shape[0] for y in df_train.columns]})
miss.sort_values(by='Count_',ascending=False)
# Out:
#      Col_name  Missing Value?  Count_  Percentage
# 0    datetime           False       0         0.0
# 1      season           False       0         0.0
# 2     holiday           False       0         0.0
# 3  workingday           False       0         0.0
# 4     weather           False       0         0.0
# 5        temp           False       0         0.0
# 6       atemp           False       0         0.0
# 7    humidity           False       0         0.0
# 8   windspeed           False       0         0.0
# 9      Target           False       0         0.0

# %%
#Checkling Missing Values - Test Data
miss=pd.DataFrame({'Col_name':df_test.columns,'Missing Value?':[any(df_test[x].isnull()) for x in df_test.columns],'Count_': [sum(df_test[y].isnull()) for y in df_test.columns],
                  'Percentage':[sum(df_test[y].isnull())/df_test.shape[0] for y in df_test.columns]})
miss.sort_values(by='Count_',ascending=False)
# Out:
#      Col_name  Missing Value?  Count_  Percentage
# 0    datetime           False       0         0.0
# 1      season           False       0         0.0
# 2     holiday           False       0         0.0
# 3  workingday           False       0         0.0
# 4     weather           False       0         0.0
# 5        temp           False       0         0.0
# 6       atemp           False       0         0.0
# 7    humidity           False       0         0.0
# 8   windspeed           False       0         0.0
# 9      Target           False       0         0.0

# %%
df_train.describe(include='all')
# Out:
#                 datetime  season      holiday   workingday  \
# count               8708    8708  8708.000000  8708.000000
# unique              8708       4          NaN          NaN
# top     11/17/2011 14:00  Summer          NaN          NaN
# freq                   1    2197          NaN          NaN
# mean                 NaN     NaN     0.028480     0.680294
# std                  NaN     NaN     0.166348     0.466389
# min                  NaN     NaN     0.000000     0.000000
# 25%                  NaN     NaN     0.000000     0.000000
# 50%                  NaN     NaN     0.000000     1.000000
# 75%                  NaN     NaN     0.000000     1.000000
# max                  NaN     NaN     1.000000     1.000000
#
#                     weather         temp        atemp     humidity  \
# count                  8708  8708.000000  8708.000000  8708.000000
# unique                    4          NaN          NaN          NaN
# top      Clear + Few clouds          NaN          NaN          NaN
# freq                   5753          NaN          NaN          NaN
# mean                    NaN    20.243020    23.655552    61.649173
# std                     NaN     7.813494     8.501107    19.199578
# min                     NaN     0.820000     0.760000     0.000000
# 25%                     NaN    13.940000    16.665000    46.000000
# 50%                     NaN    20.500000    24.240000    61.000000
# 75%                     NaN    26.240000    31.060000    77.000000
# max                     NaN    41.000000    45.455000   100.000000
#
#           windspeed       Target
# count   8708.000000  8708.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      12.843891   193.007005
# std        8.190314   181.552211
# min        0.000000     1.000000
# 25%        7.001500    43.000000
# 50%       12.998000   148.000000
# 75%       16.997900   286.000000
# max       56.996900   977.000000

# %% [markdown]
# * Inference - There is no null values in the train and test data.
# * By descibing the train dataset we can infer that
#     * holiday and workingday are havinig boolean values
#     * weather - 4 Unique values
#     * temp - avg temp 20.24 Deg, lowest 0.82 deg and max is 41 deg
#     * atemp - feel like temperature, looks like variation is similar like temperature, need to be checked.
#     * humidity range from 0 to 100 %
#     * windspeed ranges from 0 to 57
#     * Booking perday ranges from 1 to 977

# %%
df_test.describe(include='all')
# Out:
#                datetime  season      holiday   workingday  \
# count              2178    2178  2178.000000  2178.000000
# unique             2178       4          NaN          NaN
# top     1/17/2011 13:00  Spring          NaN          NaN
# freq                  1     550          NaN          NaN
# mean                NaN     NaN     0.028926     0.683196
# std                 NaN     NaN     0.167636     0.465337
# min                 NaN     NaN     0.000000     0.000000
# 25%                 NaN     NaN     0.000000     0.000000
# 50%                 NaN     NaN     0.000000     1.000000
# 75%                 NaN     NaN     0.000000     1.000000
# max                 NaN     NaN     1.000000     1.000000
#
#                     weather         temp        atemp     humidity  \
# count                  2178  2178.000000  2178.000000  2178.000000
# unique                    3          NaN          NaN          NaN
# top      Clear + Few clouds          NaN          NaN          NaN
# freq                   1439          NaN          NaN          NaN
# mean                    NaN    20.182241    23.653214    62.835170
# std                     NaN     7.704978     8.369721    19.401161
# min                     NaN     3.280000     3.790000     0.000000
# 25%                     NaN    13.940000    16.665000    48.000000
# 50%                     NaN    20.500000    24.240000    63.000000
# 75%                     NaN    26.240000    31.060000    78.000000
# max                     NaN    38.540000    44.695000   100.000000
#
#           windspeed       Target
# count   2178.000000  2178.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      12.621496   185.845271
# std        8.060062   179.431987
# min        0.000000     1.000000
# 25%        7.001500    38.000000
# 50%       11.001400   136.000000
# 75%       16.997900   277.000000
# max       56.996900   901.000000

# %% [markdown]
# * Inference - There is no null values in the train and test data.
# * By descibing the train dataset we can infer that
#     * holiday and workingday are havinig boolean values
#     * weather - 3 Unique values
#     * temp - avg temp 20.50 Deg, lowest 3.38 deg and max is 38.54 deg
#     * atemp - feel like temperature, looks like variation is similar like temperature, need to be checked.
#     * humidity range from 0 to 100 %
#     * windspeed ranges from 0 to 57
#     * Booking perday ranges from 1 to 901

# %%
# Data Visualization - historgam 

def draw_histograms(df, features, rows, cols):
    fig=plt.figure(figsize=(20,20))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        df[feature].hist(bins=20,ax=ax,facecolor='midnightblue')
        ax.set_title(feature+"Distribution",color='DarkRed')
        
    fig.tight_layout()
    plt.show()

# %%
#Plotting the histograms
columns=['temp','atemp','humidity','windspeed','Target']
draw_histograms(df_train,columns,3,2)

# %% [markdown]
# # Inference
#  * The continuous variables are selcted manually as the dataset in small and features are limited.
#  * We can see that temp and atemp distribution both has two peaks.
#  * Humidity distribution is some what normally distributed
#  * Wind Speed - Not normally distributed. For values 5-6, there is no data.
#  * No of Booking is Positively skewed.
#
#
#  * All the features are not distributed normally, so we can take log of the values of the features and compare the lognormal values with the target distribution whihc is no.of booking

# %%
# Converting to datetime and extracting the parameters of datetime as features

df_train['datetime']=pd.to_datetime(df_train['datetime'])
df_train['day']=df_train.datetime.dt.day
df_train['month']=df_train.datetime.dt.month
df_train['year']=df_train.datetime.dt.year
df_train['time']=df_train.datetime.dt.time
df_train['date']=df_train.datetime.dt.date

# %%
df_train.head()
# Out:
#              datetime  season  holiday  workingday              weather  \
# 0 2012-05-02 19:00:00  Summer        0           1   Clear + Few clouds
# 1 2012-09-05 04:00:00    Fall        0           1   Clear + Few clouds
# 2 2011-01-13 09:00:00  Spring        0           1   Clear + Few clouds
# 3 2011-11-18 16:00:00  Winter        0           1   Clear + Few clouds
# 4 2011-09-13 13:00:00    Fall        0           1   Clear + Few clouds
#
#     temp   atemp  humidity  windspeed  Target  day  month  year      time  \
# 0  22.14  25.760        77    16.9979     504    2      5  2012  19:00:00
# 1  28.70  33.335        79    19.0012       5    5      9  2012  04:00:00
# 2   5.74   6.060        50    22.0028     139   13      1  2011  09:00:00
# 3  13.94  16.665        29     8.9981     209   18     11  2011  16:00:00
# 4  30.34  33.335        51    19.0012     184   13      9  2011  13:00:00
#
#          date
# 0  2012-05-02
# 1  2012-09-05
# 2  2011-01-13
# 3  2011-11-18
# 4  2011-09-13

# %%
# when its not a holiday and not a working day, it can be considered to a weekend. Introducing that feature to the dataframe.
df_train['weekend']=1-(df_train.holiday +df_train.workingday)
df_train.head()
# Out:
#              datetime  season  holiday  workingday              weather  \
# 0 2012-05-02 19:00:00  Summer        0           1   Clear + Few clouds
# 1 2012-09-05 04:00:00    Fall        0           1   Clear + Few clouds
# 2 2011-01-13 09:00:00  Spring        0           1   Clear + Few clouds
# 3 2011-11-18 16:00:00  Winter        0           1   Clear + Few clouds
# 4 2011-09-13 13:00:00    Fall        0           1   Clear + Few clouds
#
#     temp   atemp  humidity  windspeed  Target  day  month  year      time  \
# 0  22.14  25.760        77    16.9979     504    2      5  2012  19:00:00
# 1  28.70  33.335        79    19.0012       5    5      9  2012  04:00:00
# 2   5.74   6.060        50    22.0028     139   13      1  2011  09:00:00
# 3  13.94  16.665        29     8.9981     209   18     11  2011  16:00:00
# 4  30.34  33.335        51    19.0012     184   13      9  2011  13:00:00
#
#          date  weekend
# 0  2012-05-02        0
# 1  2012-09-05        0
# 2  2011-01-13        0
# 3  2011-11-18        0
# 4  2011-09-13        0

# %%
df_train.weekend.value_counts()
# Out:
# 0    6172
# 1    2536
# Name: weekend, dtype: int64

# %% [markdown]
# # Checking for the outliers

# %%
# Calculating IQR score for all the columns

Q1=df_train.quantile(0.25)
Q3=df_train.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# holiday         0.0000
# workingday      1.0000
# temp           12.3000
# atemp          14.3950
# humidity       31.0000
# windspeed       9.9964
# Target        243.0000
# day            10.0000
# month           6.0000
# year            1.0000
# weekend         1.0000
# dtype: float64

# %%
feat=['temp','atemp','humidity','windspeed','Target']
X=df_train[feat]

# %%
#Plotting the box plot
plt.figure(figsize=(10,5))
sns.boxplot(data=X)
plt.xticks(ticks=np.arange(len(feat)),labels=feat)
plt.show()

# %% [markdown]
# # Inference_Outlier_1
# * From the above we can see that for, temp,atemp and humidity there is not outlier.
# * For windspeed there are outlier - need to understand the relation between these outlier values and booking with those between IQR in order to take decision whether to discard them or not.
# * Target or Booking is being observed to have considerable number of outliers.
# * Here, we need to understand whether we can extract some information for the outliers or not.
# * Outlier donot exist below the lower quartile.

# %%
# Extracting the index of the dataframe, for which outlier exist in the Target column 
X_outl_index=df_train[((df_train.Target<(Q1.Target-1.5*IQR.Target)) | (df_train.Target>(Q3.Target+1.5*IQR.Target)))].index
X_wo_outl_index=df_train[~((df_train.Target<(Q1.Target-1.5*IQR.Target)) | (df_train.Target>(Q3.Target+1.5*IQR.Target)))].index

# %%
# Extracting the index of the dataframe, for which outlier exist in the Windspeed column 

X_outl_index_wind=df_train[((df_train.windspeed<(Q1.windspeed-1.5*IQR.windspeed)) | (df_train.windspeed>(Q3.windspeed+1.5*IQR.windspeed)))].index
X_wo_outl_index_wind=df_train[~((df_train.windspeed<(Q1.windspeed-1.5*IQR.windspeed)) | (df_train.windspeed>(Q3.windspeed+1.5*IQR.windspeed)))].index

# %%
# For Target - creating a dataframe with index with outlier in Target/booking and with out outlier in Target/booking.
df_outlier=df_train.iloc[X_outl_index]
df_not_outlier=df_train.iloc[X_wo_outl_index]

# %%
#Season
season_grp_out=df_outlier.groupby('season')['Target'].sum().sort_values(ascending=False)
plt.bar(season_grp_out.index,season_grp_out.values)
plt.title("Variation of Booking season wise with outlier data",color='DarkRed')
plt.show()
season_grp_not_out=df_not_outlier.groupby('season')['Target'].sum().sort_values(ascending=False)
plt.bar(season_grp_not_out.index,season_grp_not_out.values)
plt.title("Variation of Booking season wise with non-outlier data",color='DarkRed')
plt.show()

# %% [markdown]
# * Here variation of sum of booking season-wise, re-inforces the observation of that without outliers data. A decresing trend from fall to spring is oberved.

# %%
#Weather
weather_grp_out=df_outlier.groupby('weather')['Target'].sum().sort_values(ascending=False)
plt.bar(weather_grp_out.index,weather_grp_out.values)
plt.title("Variation of Booking weather-wise with outlier data",color='DarkRed')
plt.show()

weather_grp_not_out=df_not_outlier.groupby('weather')['Target'].sum().sort_values(ascending=False)
plt.bar(weather_grp_not_out.index,weather_grp_not_out.values)
plt.title("Variation of Booking weather-wise with non-outlier data",color='DarkRed')
plt.show()

# %% [markdown]
# * Here variation of sum of booking weather-wise, re-inforces the observation of that without outliers data. Sum of booking is more in case of outlier data compared to non-outlier data.

# %%
#Month
month_grp_out=df_outlier.groupby('month')['Target'].sum().sort_values(ascending=False)
plt.bar(month_grp_out.index,month_grp_out.values)
plt.title("Variation of Booking month-wise with outlier data",color='DarkRed')
plt.show()

month_grp_not_out=df_not_outlier.groupby('month')['Target'].sum().sort_values(ascending=False)
plt.bar(month_grp_not_out.index,month_grp_not_out.values)
plt.title("Variation of Booking month-wise with non-outlier data",color='DarkRed')
plt.show()

# %%
# Hour-wise Booking
plt.bar(df_train.datetime.dt.hour,df_train.Target)
plt.title("Day Hour Vs Booking")
plt.show()

# %% [markdown]
# * From the above, we can see that in early hours of the day, booking is low.
# * Two signicant peaks are observed, one near 7:00 to 8:00 hours and other 17:00 and 18:00 hours
# * A steady booking is observed 10:00-1500 hours

# %%
#Checking the time-wise sum of peak booking 
df_temp=df_outlier[['Target','time']]
df_temp['time_bins']=pd.cut(x=pd.to_datetime(df_outlier.datetime).dt.hour,bins=[0,5,10,15,20,24],labels=['c1','c2','c3','c4','c5'])
time_grp=df_temp.groupby('time_bins')['Target'].sum().sort_values(ascending=False)
plt.bar(time_grp.index,time_grp.values)
plt.xticks(time_grp.index)
plt.title("Hours bins Vs Booking - Outlier Data")
plt.show()

df_temp_1=df_not_outlier[['Target','time']]
df_temp_1['time_bins']=pd.cut(x=pd.to_datetime(df_not_outlier.datetime).dt.hour,bins=[0,5,10,15,20,24],labels=['c1','c2','c3','c4','c5'])
time_grp=df_temp_1.groupby('time_bins')['Target'].sum().sort_values(ascending=False)
plt.bar(time_grp.index,time_grp.values)
plt.xticks(time_grp.index)
plt.title("Hours bins Vs Booking - Non-Outlier Data")
plt.show()
# Out:
# C:\Users\jbhsm\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\jbhsm\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# * To be noted here, when observing sum of booking with respect to the time slots for both in outlier and without outlier data, we see that
#     * C4 - 15:00 hrs to 20:00 hrs - we have the highest booking in both the cases.
#     * C3 & C2 we see peak booking, after C4.
#     * For C2 and C1 no peak booking is observed.
# * The observation on outlier data re-inforces the observation in non-outlier data.

# %%
plt.figure(figsize=(8,5))
plt.bar(df_train.iloc[X_outl_index_wind].windspeed,df_train.iloc[X_outl_index_wind].Target)
plt.title("windspeed Outlier Vs Booking",color='DarkRed')
plt.show()
plt.bar(df_train.iloc[X_wo_outl_index_wind].windspeed,df_train.iloc[X_wo_outl_index_wind].Target)
plt.title("windspeed Non_Outlier Vs Booking",color='DarkRed')
plt.show()

# df[feature].hist(bins=20,ax=ax,facecolor='midnightblue')

# %% [markdown]
# # Inference_Outlier_2
# * With high wind speed total booking reduces.
# * There are total 182 outlier values.
# * With windspeed between 0-30, booking is almost constant. As wind speed increases more than 33, booking decreases. This clearly shows that even outlier carries some information about the booking and may not be excluded.

# %% [markdown]
# # Inference
#
# * We will consider all the feature including it outlier.
#     * Windspeed - though a decreasing gradient is observed with increase in windspeed, but this is not contradicting the observation without outlier - as in without outlier data, the windspeed ranges from 0-30, above that total booking drops - this can be taken as information.
#
#     * Target/Booking - Outlier re-inforces that non-outlier data, and more so we need to ensure availablility of more vehile duriing peak hours, we can take this as information and include as it is our model preparation.

# %% [markdown]
# # Understanding the varition of other features with respect to the target variable

# %%
wrk_day_grp=df_train.groupby('workingday')['Target'].sum().sort_values(ascending=False)

plt.bar(wrk_day_grp.index,wrk_day_grp.values)
plt.xticks(wrk_day_grp.index)
plt.title("Working Days Vs Booking")
plt.show()

# %%
wk_end_grp=df_train.groupby('weekend')['Target'].sum().sort_values(ascending=False)
plt.bar(wk_end_grp.index,wk_end_grp.values)
plt.xticks(wk_end_grp.index)
plt.title("Weekends Vs Booking")
plt.show()

# %%
hol_grp=df_train.groupby('holiday')['Target'].sum().sort_values(ascending=False)
plt.bar(hol_grp.index,hol_grp.values)
plt.xticks(hol_grp.index)
plt.title("Holidays Vs Booking")
plt.show()

# %% [markdown]
# * From the three graphs above, we get the maximum information from Holiday Vs Booking, since for non-holidays the booking is highest and for holidays they are lowest.

# %%
#Variation of total booking basis year
yr_grp=df_train.groupby('year')['Target'].sum().sort_values(ascending=False)
plt.bar(yr_grp.index,yr_grp.values)
plt.xticks(yr_grp.index)
plt.title("Year Vs Booking")
plt.show()

# %% [markdown]
# * Increase trend of booking year in year basis is observed

# %%
plt.figure(figsize=(8,5))
plt.bar(df_train.humidity,df_train.Target)
plt.title("Humidity Vs Booking",color='DarkRed')
plt.show()

# %% [markdown]
# * No definite trend is observed, at higher and lower humidity booking is lower

# %% [markdown]
# # Correlation Matrix

# %%
fig=plt.figure(figsize=(15,10))
sns.heatmap(df_train.corr(), annot=True, cmap='RdGy')
plt.show()

# %% [markdown]
# # Inference - Correlation
#
#     * Both temp and atemp are varying in a similar manner, hence one can be dropped, as both of then are giving similar information.
#     * Holiday, weekend and workingday basically describing the day. Workingday and Holiday combined are giving us lot of info.

# %% [markdown]
# # Preparing the Training and Test Dataset basis the information received above:

# %% [markdown]
# ## Training Data Set

# %%
# Introducing the bins in the training dataset
df_train['time_bins']=pd.cut(x=pd.to_datetime(df_train.datetime).dt.hour,bins=[0,5,10,15,20,24],labels=['c1','c2','c3','c4','c5'])

# %%
#Dropping the columns with unique values and re-arranging the columns
train_X=df_train.drop(["datetime","date","day","time",'temp','Target','weekend'],axis=1)
train_X=train_X[['season','weather','time_bins','year','workingday','holiday','atemp','humidity','windspeed','month']]

# %%
train_y=df_train.Target

# %% [markdown]
# * Categorical values in both train and test dataset need to converted to their respective dummy values

# %%
train_X_dum=pd.get_dummies(data=train_X,columns=['month','season','weather','time_bins','year'])

# %%
# applying min_max scaler to the data set
from sklearn.preprocessing import MinMaxScaler
df_temp=train_X_dum[['atemp','humidity','windspeed']]
min_max=MinMaxScaler()
trfd_array = min_max.fit_transform(df_temp)
train_X_dum['atemp']=trfd_array[:,0]
train_X_dum['humidity']=trfd_array[:,1]
train_X_dum['windspeed']=trfd_array[:,2]

# %%
# Removing 'weather_ Heavy Rain + Thunderstorm' column from the train dataset - as there is not data of no.of booking against this feature.
columns_drop_train=['month_1','season_Fall','weather_ Heavy Rain + Thunderstorm ','time_bins_c1','year_2011']
train_X_final=train_X_dum.drop(columns_drop_train, axis=1)

# %% [markdown]
# ## Test Data Set

# %%
# Extracting datatime features
df_test['datetime']=pd.to_datetime(df_test['datetime'])
df_test['day']=df_test.datetime.dt.day
df_test['month']=df_test.datetime.dt.month
df_test['year']=df_test.datetime.dt.year
df_test['time']=df_test.datetime.dt.time
df_test['date']=df_test.datetime.dt.date

# %%
df_test['time_bins']=pd.cut(x=pd.to_datetime(df_test.datetime).dt.hour,bins=[0,5,10,15,20,24],labels=['c1','c2','c3','c4','c5'])

# %%
# Creating the final test data set
test_X=df_test.drop(["datetime","date","day","time",'temp','Target'],axis=1)

# %%
test_X=test_X[['season','weather','time_bins','year','workingday','holiday','atemp','humidity','windspeed','month']]

# %%
test_X_dum=pd.get_dummies(data=test_X,columns=['month','season','weather','time_bins','year'])

# %%
# Processing temperature, humidity and windspeed for test data
df_temp_test=test_X_dum[['atemp','humidity','windspeed']]
min_max_test=MinMaxScaler()
trfd_array_test = min_max_test.fit_transform(df_temp_test)
test_X_dum['atemp']=trfd_array_test[:,0]
test_X_dum['humidity']=trfd_array_test[:,1]
test_X_dum['windspeed']=trfd_array_test[:,2]

# %%
# removing the requisite columns from test data set - this will decrease the muilti-coliniearity
columns_drop_test=['month_1','season_Fall','time_bins_c1','year_2011']
test_X_final=test_X_dum.drop(columns_drop_test, axis=1)

# %%
test_y=df_test.Target

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %%
params_reg = {'n_estimators':[200,300],'criterion': ['mse'],'max_depth':[8],'min_samples_split':[5,8],
              'min_samples_leaf':[5,8]}

# %%
clf=RandomForestRegressor(random_state=0)

# %%
grid_obj = GridSearchCV(clf,params_reg)

# %%
grid_obj.fit(train_X_final,train_y)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=0,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['mse'], 'max_depth': [8],
#                          'min_samples_leaf': [5, 8],
#                          'min_samples_split': [5, 8],
#                          'n_estimators': [200, 300]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
grid_obj.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=8, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=5, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
grid_obj.best_score_
# Out:
# 0.7537923330154825

# %%
grid_results=pd.DataFrame(grid_obj.cv_results_)

# %%
grid_obj.cv_results_['params'][0]
# Out:
# {'criterion': 'mse',
#  'max_depth': 8,
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
clf_best=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=8, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=5,
                      min_samples_split=5, min_weight_fraction_leaf=0.0,
                      n_estimators=300, n_jobs=None, oob_score=False,
                      random_state=0, verbose=0, warm_start=False)

# %%
clf_best.fit(train_X_final,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=8, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=5, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred=clf_best.predict(test_X_final)

# %%
from sklearn.metrics import mean_squared_error

# %%
score_mse=mean_squared_error(test_y,y_pred)
print("The model mean-square-error is: ", round(score_mse,2))
# Out:
# The model mean-square-error is:  7762.81

# %% [markdown]
# # Further Analysis

# %%
fig=plt.figure(figsize=(30,10))
plt.plot(test_y[0:300], label='Actual_y',color='r')
plt.plot(y_pred[0:300], label='Grd_bst_y',color='g')
# plt.xticks(range(0,300))
plt.legend()
plt.title("Booking Prediction Vs Actual")
plt.show()

# %%
dict_temp={}
dict_temp['actual']=test_y
dict_temp['predicted']=y_pred

# %%
predict_df=pd.DataFrame(dict_temp)

# %%
predict_df.head()
# Out:
#    actual   predicted
# 0     256  263.408901
# 1      87  173.547919
# 2      11   46.132656
# 3      84  137.158195
# 4     668  592.433608

# %%
predict_df["pred_type"]=predict_df.actual-predict_df.predicted
predict_df['pred_bias']=predict_df.pred_type.tolist()
predict_df['pred_bias']=predict_df['pred_bias'].map(lambda x: 'Over' if x<0 else 'Under')
predict_df['percent_pred']= round(((np.absolute(predict_df.pred_type)/predict_df.actual)*100),2)
predict_df['book_bins']=pd.cut(x=predict_df.actual,bins=[0,200,400,600,800,1000])

# %%
book_bin_grp=predict_df[predict_df.pred_bias=='Over'].groupby('book_bins')['percent_pred'].mean()

# %%
book_bin_grp
# Out:
# book_bins
# (0, 200]       180.442913
# (200, 400]      21.542949
# (400, 600]      16.532692
# (600, 800]       5.590000
# (800, 1000]           NaN
# Name: percent_pred, dtype: float64

# %% [markdown]
# # Inference on prediction - Over Prediction
#     * There is over prediction, that means that based on the feature model will predict more than required.
#     * To be noted here that where the requirement is upto 200%, the prediction is 180% more.
#     * In over upper ranges the average percentage variation ins lower.

# %%
book_bin_grp=predict_df[predict_df.pred_bias=='Under'].groupby('book_bins')['percent_pred'].mean()
book_bin_grp
# Out:
# book_bins
# (0, 200]       30.554147
# (200, 400]     22.784245
# (400, 600]     27.049548
# (600, 800]     32.590597
# (800, 1000]    32.308462
# Name: percent_pred, dtype: float64

# %% [markdown]
# # Inference on prediction - Under Prediction
#     * Under prediction average percentage is almost same in all the ranges, since over prediction is more than under-prediction in the same range, we can say that model will always over predicts and avaiability of cab will be more than required.
#     * But resourse allocation (Cab) will be more, hence a capping may need to be provided when total prediction is in the range of 0-200

# %%
df_inf_test=test_X.copy()

# %%
df_inf_test=df_inf_test.join(df_test.Target)

# %%
df_inf_test.head()
# Out:
#    season                  weather time_bins  year  workingday  holiday  \
# 0  Summer       Clear + Few clouds        c3  2012           1        0
# 1  Summer       Clear + Few clouds        c2  2012           0        0
# 2  Spring   Light Snow, Light Rain        c4  2011           0        0
# 3  Winter           Mist + Cloudy         c3  2011           1        0
# 4  Summer       Clear + Few clouds        c3  2012           0        0
#
#     atemp  humidity  windspeed  month  Target
# 0  25.000        48    35.0008      5     256
# 1  27.275        64     7.0015      6      87
# 2  12.120       100    27.9993      3      11
# 3  28.790        83     0.0000     10      84
# 4  31.060        43    23.9994      6     668

# %%
df_inf_test['booking_bins']=pd.cut(x=df_inf_test.Target,bins=[0,200,400,600,800,1000],labels=['0-200','201-400','401-600','601-800','801-1000'])

# %%
df_inf_test.head()
# Out:
#    season                  weather time_bins  year  workingday  holiday  \
# 0  Summer       Clear + Few clouds        c3  2012           1        0
# 1  Summer       Clear + Few clouds        c2  2012           0        0
# 2  Spring   Light Snow, Light Rain        c4  2011           0        0
# 3  Winter           Mist + Cloudy         c3  2011           1        0
# 4  Summer       Clear + Few clouds        c3  2012           0        0
#
#     atemp  humidity  windspeed  month  Target booking_bins
# 0  25.000        48    35.0008      5     256      201-400
# 1  27.275        64     7.0015      6      87        0-200
# 2  12.120       100    27.9993      3      11        0-200
# 3  28.790        83     0.0000     10      84        0-200
# 4  31.060        43    23.9994      6     668      601-800

# %%
df_inf_test.groupby('booking_bins')['season'].value_counts()
# Out:
# booking_bins  season
# 0-200         Spring    444
#               Winter    339
#               Summer    302
#               Fall      293
# 201-400       Fall      155
#               Winter    141
#               Summer    139
#               Spring     77
# 401-600       Fall       74
#               Summer     66
#               Winter     43
#               Spring     24
# 601-800       Summer     26
#               Winter     20
#               Fall       17
#               Spring      5
# 801-1000      Fall        5
#               Winter      5
#               Summer      3
# Name: season, dtype: int64

# %%
df_inf_test.groupby('booking_bins')['weather'].value_counts()
# Out:
# booking_bins  weather
# 0-200          Clear + Few clouds        858
#                Mist + Cloudy             377
#                Light Snow, Light Rain    143
# 201-400        Clear + Few clouds        346
#                Mist + Cloudy             133
#                Light Snow, Light Rain     33
# 401-600        Clear + Few clouds        168
#                Mist + Cloudy              37
#                Light Snow, Light Rain      2
# 601-800        Clear + Few clouds         56
#                Mist + Cloudy               9
#                Light Snow, Light Rain      3
# 801-1000       Clear + Few clouds         11
#                Mist + Cloudy               2
# Name: weather, dtype: int64

# %%
df_inf_test.groupby('booking_bins')['time_bins'].value_counts()
# Out:
# booking_bins  time_bins
# 0-200         c1           462
#               c2           254
#               c5           224
#               c3           217
#               c4           116
# 201-400       c3           180
#               c4           169
#               c2           114
#               c5            49
# 401-600       c4           116
#               c2            51
#               c3            40
# 601-800       c4            40
#               c2            19
#               c3             9
# 801-1000      c4            11
#               c2             2
# Name: time_bins, dtype: int64

# %% [markdown]
# # Inference
# * The model will always ensure that more cabs are available than requirement, hence minimum business loss.
# * To optimize resource utlization:
#     * From the above we note that, in the prediction range 0-200, which is showing maximum over prediction, are the booking rediction is done in C1 and C2 category - during night and early morning time.
#     * A capping may be provided in this section and model may be improved further.
#     * While having a combined combination of condition of vehicle during night/early morning or "Clear and Few Clouds" or "Spring" some caution in provision of cab may be exercise.
